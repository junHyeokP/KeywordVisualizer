# %% [markdown]
# # 1. 네이버 뉴스 Crawling with Naver Open API
# - 네이버 개발자 가입 : 서비스 API > 검색 > [오픈 API 이용 신청]
# - 검색 API 사용 신청 : Products > 검색 > [오픈 API 이용 신청]
#
# https://developers.naver.com/main/

# %%
# 네이버 검색 API 예제 -  블로그 검색 예제를 뉴스 검색 예제로 수정하여 실행
# 네이버 검색 API 예제 - 블로그 검색
import os
import sys
import urllib.request

client_id = "8os69VYnBk5H5QpLkte1"
client_secret = "kPicTeAw_3"

# 한글 검색어 안전하게 변환
encText = urllib.parse.quote("인공지능")

# url + query 생성
# url = "https://openapi.naver.com/v1/search/"검색필터 넣는 곳".xml?query=" + encText
url = "https://openapi.naver.com/v1/search/news?query=" + encText # JSON 결과
start = 1
display = 10
rescode = 200

while rescode == 200 and start < 30 :
    # request message 구성
    new_url = url + f"&start={start}&display={display}"
    request = urllib.request.Request(new_url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)

    # request -> response 받아오기
    response = urllib.request.urlopen(request)
    
    # 받아온 결과가 정상인지 확인
    rescode = response.getcode()
    if(rescode==200):
        # 정상이면 데이터 읽어오기
        response_body = response.read()
        print(response_body.decode('utf-8')) # 한글이 있을 시 utf-8
    else:
        print("Error Code:" + rescode)
        
    start += display
# Out:
# {
# 	"lastBuildDate":"Fri, 18 Apr 2025 15:25:46 +0900",
# 	"total":2879160,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"율촌화학, 포승 신공장 가동…배터리 파우치 생산 확대",
# 			"originallink":"http:\/\/www.thelec.kr\/news\/articleView.html?idxno=35108",
# 			"link":"http:\/\/www.thelec.kr\/news\/articleView.html?idxno=35108",
# 			"description":"무결점 합지·코팅을 위한 생산 라인과 <b>인공지능<\/b>(AI) 기반 품질 검사 시스템을 갖춘 클린룸 환경을 구축했다. 율촌화학은 2019년 국내 최초로 알루미늄 파우치 국산화에 성공했다. 2023년부터는 기존 대비 두께가 약 20... ",
# 			"pubDate":"Fri, 18 Apr 2025 15:24:00 +0900"
# 		},
# 		{
# 			"title":"KITA 'AI 활용법' 세미나 개최",
# 			"originallink":"https:\/\/www.koreadaily.com\/article\/20250417232237422",
# 			"link":"https:\/\/www.koreadaily.com\/article\/20250417232237422",
# 			"description":"캘리포니아한국기업협회(KITA.회장 김한수)가 지난 17일 오전 11시에 <b>인공지능<\/b>(AI 활용법)을 소개하는 웨비나를 개최했다. 이날 한국과 아시아 최초 구글 클라우드 파트너사이면서 한국 최초의 제미나이 AI 공급 기업인... ",
# 			"pubDate":"Fri, 18 Apr 2025 15:24:00 +0900"
# 		},
# 		{
# 			"title":"&quot;도덕성 vs 준법성&quot;…6.3 대선, '정책' 대신 '인물' 대결 예고",
# 			"originallink":"https:\/\/www.pinpointnews.co.kr\/news\/articleView.html?idxno=337628",
# 			"link":"https:\/\/www.pinpointnews.co.kr\/news\/articleView.html?idxno=337628",
# 			"description":"이 전 대표는 2월 국회 교섭단체 연설에서 &quot;AI(<b>인공지능<\/b>)와 첨단 기술 발전에 따른 생산성 향상은 노동시간 단축으로 이어져야 한다&quot;며, 주 4.5일제를 거쳐 장기적으로 주 4일제 국가로 가야 한다는 입장을 밝혔다. 국민의힘... ",
# 			"pubDate":"Fri, 18 Apr 2025 15:24:00 +0900"
# 		},
# 		{
# 			"title":"모모성형외과, 국내 첫 AI모발이식 시스템 “아타스iX” 도입",
# 			"originallink":"https:\/\/www.seoul.co.kr\/news\/economy\/2025\/04\/18\/20250418500133?wlog_tag3=naver",
# 			"link":"https:\/\/n.news.naver.com\/mnews\/article\/081\/0003534736?sid=101",
# 			"description":"- 아타스iX, 전세계 유일의 지능형 <b>인공지능<\/b>(AI) 모발이식 로봇수술 시스템 - 모발 채취에서 식립까지 전 과정 자동화... 휴먼에러 없애고 수술 정확성, 안정성 혁신적 개선 모모성형외과(대표원장 김승준)가 국내 최초로... ",
# 			"pubDate":"Fri, 18 Apr 2025 15:23:00 +0900"
# 		},
# 		{
# 			"title":"1.8조 들여 최신 GPU 1만장 확보 &quot;엔비디아에 확인, 확보 문제 없어&quot;",
# 			"originallink":"https:\/\/www.joongang.co.kr\/article\/25329581",
# 			"link":"https:\/\/n.news.naver.com\/mnews\/article\/025\/0003435077?sid=101",
# 			"description":"정부가 <b>인공지능<\/b>(AI) 생태계 혁신을 위한 1조8000억원 규모의 추가 예산을 18일 임시국무회의에서 심의한 추가경정예산안에 담았다. AI 추경 편성의 대부분(1조4600억원)은 H200·블랙웰 등 엔비디아의 최신 고성능 GPU... ",
# 			"pubDate":"Fri, 18 Apr 2025 15:23:00 +0900"
# 		},
# 		{
# 			"title":"중기부, 올해 추경예산안 '5조112억원' 편성",
# 			"originallink":"https:\/\/news.mtn.co.kr\/news-detail\/2025041808334454127",
# 			"link":"https:\/\/news.mtn.co.kr\/news-detail\/2025041808334454127",
# 			"description":"중소벤처기업부가 통상문제, 산불피해, 더딘 내수회복과 AI발 기술경쟁 등 당면한 대내외 위기 극복을 위해 올해 추경예산안 5조112억원을 마련했다고 18일 밝혔다.통상리스크 대응 지원, 민생회복 지원, AI(<b>인공지능<\/b>) 등... ",
# 			"pubDate":"Fri, 18 Apr 2025 15:22:00 +0900"
# 		},
# 		{
# 			"title":"[현장] &quot;누구에게나 무료&quot;···AWS, AI 공공부문 문 열다",
# 			"originallink":"http:\/\/www.enewstoday.co.kr\/news\/articleView.html?idxno=2266238",
# 			"link":"http:\/\/www.enewstoday.co.kr\/news\/articleView.html?idxno=2266238",
# 			"description":"AI 기술이 산업계를 넘어 공공 영역으로 점차 확산하고 있는 가운데 글로벌 클라우드 기업 아마존웹서비스(AWS)와 국내 <b>인공지능<\/b>(AI) 스타트업 업스테이지가 공공분야 AI 활용을 위한 민간 차원의 협력 방향을 제시했다.... ",
# 			"pubDate":"Fri, 18 Apr 2025 15:22:00 +0900"
# 		},
# 		{
# 			"title":"청주시, 평생학습 국‧도비 5.6억원 확보… 시민 배움 폭 확대",
# 			"originallink":"http:\/\/www.bzeronews.com\/news\/articleView.html?idxno=707782",
# 			"link":"http:\/\/www.bzeronews.com\/news\/articleView.html?idxno=707782",
# 			"description":"예산 1억원을 들여 장애 유형별 맞춤형 <b>인공지능<\/b>(AI) 교육, 장애인 시민 기록 활동가 양성, 환경 리더 역량 강화 프로그램 등을 오는 5월부터 진행해 장애인의 사회활동 참여와 성장을 지원할 예정이다. 비문해‧저학력... ",
# 			"pubDate":"Fri, 18 Apr 2025 15:21:00 +0900"
# 		},
# 		{
# 			"title":"유통학회 '춘계학술대회'…산·학 “지속가능한 생태계 구축 시급”",
# 			"originallink":"https:\/\/www.etnews.com\/20250418000229",
# 			"link":"https:\/\/n.news.naver.com\/mnews\/article\/030\/0003304761?sid=101",
# 			"description":"새로운 소비자 트렌드와 사회적 변화에 적응하면서 <b>인공지능<\/b>(AI) 등 기술 혁신을 기회로 전환해야 한다고 강조했다. 이외에 △소비자행동 및 마케팅 연구 △유통, 네트워크 전략 관련 연구 △지속가능 유통 생태계 등... ",
# 			"pubDate":"Fri, 18 Apr 2025 15:21:00 +0900"
# 		},
# 		{
# 			"title":"관세 폭풍에 돈줄 마르자…한덕수, “기업 자금 흐름 뒷받침해야”",
# 			"originallink":"https:\/\/www.joongang.co.kr\/article\/25329580",
# 			"link":"https:\/\/n.news.naver.com\/mnews\/article\/025\/0003435076?sid=100",
# 			"description":"정부는 ▶산불 피해 극복을 위한 재해·재난 대응에 3조2000억원 ▶통상·<b>인공지능<\/b>(AI) 지원에 4조4000억원 ▶소상공인·취약계층 지원에 4조3000억원을 각각 투입할 계획이다. 추경안에는 미국의 상호관세 부과에 따른... ",
# 			"pubDate":"Fri, 18 Apr 2025 15:21:00 +0900"
# 		}
# 	]
# }
# {
# 	"lastBuildDate":"Fri, 18 Apr 2025 15:25:47 +0900",
# 	"total":2879160,
# 	"start":11,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"영남권 산불·미국발 관세 충격 등에 12조 2000억원 추경안 의결…22일 ...",
# 			"originallink":"https:\/\/www.newsquest.co.kr\/news\/articleView.html?idxno=243564",
# 			"link":"https:\/\/www.newsquest.co.kr\/news\/articleView.html?idxno=243564",
# 			"description":"3대 중점 사업 분야는 ▲재해·재난 대응 3조 2000억원 ▲ 통상·<b>인공지능<\/b>(AI) 지원 4조 4000억원▲ 소상공인·취약계층 지원 4조 3000억원 등이다. 최근의 영남권에서 발생한 심각한 산불피해와 함께 다가오는 여름철 태풍... ",
# 			"pubDate":"Fri, 18 Apr 2025 15:20:00 +0900"
# 		},
# 		{
# 			"title":"한국투자증권, 손익차등형 공모펀드 목표수익률 15% 달성해 조기상환",
# 			"originallink":"http:\/\/www.fieldnews.kr\/news\/articleView.html?idxno=15631",
# 			"link":"http:\/\/www.fieldnews.kr\/news\/articleView.html?idxno=15631",
# 			"description":"이 펀드는 지난해 1월 한국투자금융그룹 계열사들이 손잡고 출시한 손익차등형 공모펀드로 ▲클라우드&amp; AI(<b>인공지능<\/b>) ▲IT시스템 ▲반도체솔루션 ▲스마트헬스케어 ▲자동화&amp;모빌리티 ▲빅테크플랫폼 ▲미래금융 등 7개... ",
# 			"pubDate":"Fri, 18 Apr 2025 15:20:00 +0900"
# 		},
# 		{
# 			"title":"국립암센터, 강원대병원과 암 진료·연구 분야 업무협약...&quot;지역 의료 격...",
# 			"originallink":"https:\/\/www.rapportian.com\/news\/articleView.html?idxno=220202",
# 			"link":"https:\/\/www.rapportian.com\/news\/articleView.html?idxno=220202",
# 			"description":"양 기관은 협약에 따라▲의료진 상호 교류 ▲국가암데이터 활용 활성화 ▲<b>인공지능<\/b> 기반 암 생존자 헬스케어 등 다양한 분야에서 협력 체계를 구축해 나갈 예정이다. 양 기관의 협력은 국가암관리 분야에서 중앙과 지역... ",
# 			"pubDate":"Fri, 18 Apr 2025 15:20:00 +0900"
# 		},
# 		{
# 			"title":"'감성 AI', 일상으로 성큼",
# 			"originallink":"http:\/\/www.newstomato.com\/ReadNews.aspx?no=1259543&inflow=N",
# 			"link":"http:\/\/www.newstomato.com\/ReadNews.aspx?no=1259543&inflow=N",
# 			"description":"뉴스토마토 = 신상민 기자 | 콘텐츠 지적재산권(IP)을 활용해 <b>인공지능<\/b>(AI) 기술에 감성을 덧입히는 시도가 잇따르고 있습니다. 네이버(NAVER(035420))웹툰과 뤼튼은 정서적 공감을 앞세운 캐릭터 챗봇으로 매출 증가... ",
# 			"pubDate":"Fri, 18 Apr 2025 15:20:00 +0900"
# 		},
# 		{
# 			"title":"[에너지 연구기관 소식] 차세대 ESS 수계아연전지로 내구성 높여",
# 			"originallink":"https:\/\/www.ekn.kr\/web\/view.php?key=20250418020198642",
# 			"link":"https:\/\/www.ekn.kr\/web\/view.php?key=20250418020198642",
# 			"description":"에기평은 지난해 '2024년 경영혁신전략 추진계획'을 수립하고, 공공기관 혁신계획 준수와 경영효율성 제고를 위하여 연구개발(R&amp;D) 고객 소통강화와 세제혜택 신설, 실증과제 예상 인허가·규제검토 및 <b>인공지능<\/b> 기반... ",
# 			"pubDate":"Fri, 18 Apr 2025 15:20:00 +0900"
# 		},
# 		{
# 			"title":"'믿을맨' AWS 한국 공공시장 정조준 &quot;물리적 망분리 환경, AI 혁신 가로막...",
# 			"originallink":"https:\/\/www.econovill.com\/news\/articleView.html?idxno=692578",
# 			"link":"https:\/\/www.econovill.com\/news\/articleView.html?idxno=692578",
# 			"description":"아마존웹서비스(AWS)가 한국 공공시장 진출을 공식화하며, <b>인공지능<\/b>(AI) 시대의 성공적인 디지털 전환을 위해서는 기존의 경직된 IT 인프라 운영 방식에서 벗어나야 한다고 강력히 주장했다. 특히 AI 활용의 필수 전제... ",
# 			"pubDate":"Fri, 18 Apr 2025 15:18:00 +0900"
# 		},
# 		{
# 			"title":"유영상 SKT 대표, 양자컴퓨터 사업확장으로 AI 기술 날개 단다",
# 			"originallink":"https:\/\/www.insightkorea.co.kr\/news\/articleView.html?idxno=222720",
# 			"link":"https:\/\/www.insightkorea.co.kr\/news\/articleView.html?idxno=222720",
# 			"description":"특히 SKT는 <b>인공지능<\/b> 비서 앱 에이닷(A.DOT) 서비스를 2023년 정식 도입해 서비스하고 있다. 양자컴퓨터를 통한 빠른 딥러닝이 가능해진다면 에이닷 성능 발전도 가속화될 가능성이 높다. 다만 양자컴퓨터 실용화가... ",
# 			"pubDate":"Fri, 18 Apr 2025 15:18:00 +0900"
# 		},
# 		{
# 			"title":"스페이스X 미 국방부에 미사일 방어 '구독 모델'로 입찰, 안두릴 팔란티...",
# 			"originallink":"https:\/\/www.businesspost.co.kr\/BP?command=article_view&num=391902",
# 			"link":"https:\/\/www.businesspost.co.kr\/BP?command=article_view&num=391902",
# 			"description":"정부가 스페이스X 소유 위성을 구독료만 내고 사용하는 방식이 거론되고 있으며 <b>인공지능<\/b>(AI) 군수 기업인 안두릴, 팔란티어도 참여한 것으로 전해진다. 18일 로이터는 상황을 잘 아는 취재원 6명 취재를 통해... ",
# 			"pubDate":"Fri, 18 Apr 2025 15:18:00 +0900"
# 		},
# 		{
# 			"title":"코어라인소프트, 日 CRO '마이크론'과 AI 영상 분석 소프트웨어 공급 계...",
# 			"originallink":"http:\/\/www.biotimes.co.kr\/news\/articleView.html?idxno=20942",
# 			"link":"http:\/\/www.biotimes.co.kr\/news\/articleView.html?idxno=20942",
# 			"description":"AVIEW COPD(사진=코어라인소프트)  코어라인소프트는 일본 CRO(임상시험수탁기관) '마이크론(Micron)'과 <b>인공지능<\/b>(AI) 기반 영상 분석 소프트웨어(SW) 'AVIEW COPD(에이뷰 씨오피디)'에 대한 공급 계약을 체결했다고 18일 밝혔다.... ",
# 			"pubDate":"Fri, 18 Apr 2025 15:16:00 +0900"
# 		},
# 		{
# 			"title":"[현장] AWS &quot;韓 AI 혁신, 논리적 망분리부터 확대해야&quot;…공공시장 본격 ...",
# 			"originallink":"https:\/\/zdnet.co.kr\/view\/?no=20250418150835",
# 			"link":"https:\/\/n.news.naver.com\/mnews\/article\/092\/0002371207?sid=105",
# 			"description":"클라우드 보안인증(CSAP) 하등급을 획득한 아마존웹서비스(AWS)가 공공부문의 <b>인공지능<\/b>(AI) 도입 확산을 위해 국내 망분리 요건을 완화해야 한다고 강조했다. AWS는 다양한 국내 기업들과의 협력 생태계를 구축하며 자사... ",
# 			"pubDate":"Fri, 18 Apr 2025 15:16:00 +0900"
# 		}
# 	]
# }
# {
# 	"lastBuildDate":"Fri, 18 Apr 2025 15:25:47 +0900",
# 	"total":2879160,
# 	"start":21,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"정부, AI·빅데이터 등 전문 민간인재 157명 국가공무원으로 선발",
# 			"originallink":"https:\/\/www.job-post.co.kr\/news\/articleView.html?idxno=143102",
# 			"link":"https:\/\/www.job-post.co.kr\/news\/articleView.html?idxno=143102",
# 			"description":"이미지 =민간경력자 일괄채용시험 홍보 포스터 정부가 <b>인공지능<\/b>(AI), 빅데이터 분석, 재난·안전관리 등 다양한 분야의 민간 전문가 157명을 국가공무원으로 선발한다. 인사혁신처는 18일 '2025년도 국가공무원 5‧7급... ",
# 			"pubDate":"Fri, 18 Apr 2025 15:16:00 +0900"
# 		},
# 		{
# 			"title":"'위믹스' 거래유의종목 5월 1주차까지 2차 연장…위메이드 &quot;최선 다해 소...",
# 			"originallink":"http:\/\/www.inews24.com\/view\/1835703",
# 			"link":"https:\/\/n.news.naver.com\/mnews\/article\/031\/0000925697?sid=105",
# 			"description":"특히 위메이드는 엔비디아와의 파트너십을 통해 <b>인공지능<\/b>(AI) 기술을 접목한 게임 환경을 구축하고 있다. 위믹스에서 선보일 신작 게임의 혁신적인 재미를 제공하기 위해서다. 1인칭슈팅(FPS) 게임 '블랙 벌처스: 프레이... ",
# 			"pubDate":"Fri, 18 Apr 2025 15:16:00 +0900"
# 		},
# 		{
# 			"title":"[현장] AWS &quot;韓 AI 혁신, 논리적 망분리부터 확대해야&quot;…공공시장 본격 ...",
# 			"originallink":"https:\/\/zdnet.co.kr\/view\/?no=20250418150835",
# 			"link":"https:\/\/n.news.naver.com\/mnews\/article\/092\/0002371207?sid=105",
# 			"description":"클라우드 보안인증(CSAP) 하등급을 획득한 아마존웹서비스(AWS)가 공공부문의 <b>인공지능<\/b>(AI) 도입 확산을 위해 국내 망분리 요건을 완화해야 한다고 강조했다. AWS는 다양한 국내 기업들과의 협력 생태계를 구축하며 자사... ",
# 			"pubDate":"Fri, 18 Apr 2025 15:16:00 +0900"
# 		},
# 		{
# 			"title":"시지메드텍, 의정부 신공장 착공…임플란트 CDMO 생산 거점 확장",
# 			"originallink":"https:\/\/www.socialvalue.kr\/news\/view\/1065593703231047",
# 			"link":"https:\/\/www.socialvalue.kr\/news\/view\/1065593703231047",
# 			"description":"정교한 생산 체계와 <b>인공지능<\/b>(AI) 시스템이 접목된 자동화 설비 등 첨단 제조 시스템도 단계적으로 적용해 나감으로써 고객 맞춤형 생산 대응력과 품질 경쟁력을 한층 끌어올릴 수 있을 것으로 기대된다. 한편, 지난해... ",
# 			"pubDate":"Fri, 18 Apr 2025 15:16:00 +0900"
# 		},
# 		{
# 			"title":"코어라인소프트, 日 CRO '마이크론'과 AI 영상 분석 소프트웨어 공급 계...",
# 			"originallink":"http:\/\/www.biotimes.co.kr\/news\/articleView.html?idxno=20942",
# 			"link":"http:\/\/www.biotimes.co.kr\/news\/articleView.html?idxno=20942",
# 			"description":"AVIEW COPD(사진=코어라인소프트)  코어라인소프트는 일본 CRO(임상시험수탁기관) '마이크론(Micron)'과 <b>인공지능<\/b>(AI) 기반 영상 분석 소프트웨어(SW) 'AVIEW COPD(에이뷰 씨오피디)'에 대한 공급 계약을 체결했다고 18일 밝혔다.... ",
# 			"pubDate":"Fri, 18 Apr 2025 15:16:00 +0900"
# 		},
# 		{
# 			"title":"충남교육청, 중등 음악교사 역량 강화 연수",
# 			"originallink":"https:\/\/view.asiae.co.kr\/article\/2025041815000912496",
# 			"link":"https:\/\/n.news.naver.com\/mnews\/article\/277\/0005580266?sid=102",
# 			"description":"'감성교육을 이끄는 미래시대 음악 교사 수업역량 강화'라는 주제 아래 열린 직무연수는 음악 교사들이 급변하는 교육 환경 속에서 <b>인공지능<\/b>(AI) 및 에듀테크 등 첨단 기술을 효과적으로 활용할 수 있도록 전문성을 높이고... ",
# 			"pubDate":"Fri, 18 Apr 2025 15:16:00 +0900"
# 		},
# 		{
# 			"title":"KTOA, 제12대 송재성 상근부회장 취임",
# 			"originallink":"http:\/\/www.edaily.co.kr\/news\/newspath.asp?newsid=03119286642137432",
# 			"link":"https:\/\/n.news.naver.com\/mnews\/article\/018\/0005991035?sid=105",
# 			"description":"송재성 KTOA 상근부회장 송재성 부회장은 취임 소감으로 “<b>인공지능<\/b> 시대로의 전환 등 통신시장 패러다임이 급변하는 시점에 중대한 소임을 맡게 되어 막중한 책임감을 느낀다”며, “회원사와의 긴밀한 소통은 물론... ",
# 			"pubDate":"Fri, 18 Apr 2025 15:15:00 +0900"
# 		},
# 		{
# 			"title":"TSMC, 1분기 순익 60.3% 급증…&quot;관세폭탄 전 사재기&quot;",
# 			"originallink":"https:\/\/www.news1.kr\/world\/general-world\/5757844",
# 			"link":"https:\/\/n.news.naver.com\/mnews\/article\/421\/0008201576?sid=104",
# 			"description":"도널드 트럼프 미국 대통령이 무역국들에 관세를 부과하고 중국이 저비용 고효율 <b>인공지능<\/b>(AI)을 내놓는 등 불확실성이 커지고 있음에도 AI 반도체 수요가 여전히 높다는 분석이다. 17일(현지시간) 로이터통신 등에... ",
# 			"pubDate":"Fri, 18 Apr 2025 15:15:00 +0900"
# 		},
# 		{
# 			"title":"딜, AI 기반 HR 솔루션 신규 출시 , 새 기능은?",
# 			"originallink":"https:\/\/economist.co.kr\/article\/view\/ecn202504180039",
# 			"link":"https:\/\/n.news.naver.com\/mnews\/article\/243\/0000076608?sid=101",
# 			"description":"인스타카트(Instacart), 타임(TIME), 도어대쉬(Doordash), 오픈AI(OpenAI), 나이키(Nike), 쇼피파이(Shopify), 에르메스(Hermes) 등 3만5000여 글로벌 기업이 사용하는 글로벌 HR 서비스 딜(Deel)이 HR 업무 효율화를 위한 <b>인공지능<\/b>... ",
# 			"pubDate":"Fri, 18 Apr 2025 15:15:00 +0900"
# 		},
# 		{
# 			"title":"울산항만공사, ‘생성형 AI 아카데미’ Chat GPT 실무교육 실시",
# 			"originallink":"https:\/\/www.wikitree.co.kr\/articles\/1043536",
# 			"link":"https:\/\/www.wikitree.co.kr\/articles\/1043536",
# 			"description":"[전국=위키트리 최학봉 선임기자] 울산항만공사(UPA, 사장 변재영)는 17일 오후 공사 다목적홀에서 직원들의 디지털 역량 강화를 위해 ‘생성형 <b>인공지능<\/b>(AI)을 활용한 실무 아카데미’를 실시했다고 밝혔다. 최근... ",
# 			"pubDate":"Fri, 18 Apr 2025 15:14:00 +0900"
# 		}
# 	]
# }

# %% [markdown]
# # 2. urllib : URL 작업용 패키지 (built-in)
# * import urllib
# * HTTP, FTP, SMTP 등과 같은 프로토콜을 사용하여 URL을 열고 읽고 쓰는 기능 제공
#
# * https://ctkim.tistory.com/entry/%ED%8C%8C%EC%9D%B4%EC%8D%AC-urllib-%EB%AA%A8%EB%93%88
#    - urllib.request : 다양한 방식으로 URL을 열고 데이터를 가져오는 기능 제공
#    - urllib.response : urllib가 사용하는 응답 클래스
#    - urllib.parse : URL 파싱, 인코딩, 디코딩
#    - urllib.robotparser : robots.txt 파일의 parsing
#
#
# ## 2-1. urllib으로 Open API 사용하기
#   - 특수문자 및 비ASCII코드를 url에 사용할 수 있도록 변경 : *string* = **urllib.parse.quote**(*string*)
#   - 요청 메시지 생성
#     - Request 객체 생성 : *request_object* = **urllib.request.Request**(*url*)
#     - Request 객체 Header에 API 사용을 위한 정보 추가 : *request_object*.**add_header(*key*, *val*)
#   - API 요청 및 결과 받기
#     - Request 객체로 url 열고 HTTPResponse 객체 받기 : *Response* = **urllib.request.urlopen**(*Request*)
#     - urlopen 결과 상태 정보 얻기 : *Response*.**getcode()** (**status**)
#     - Response 객체에서 요청 결과 얻기 : *Response*.**read()**
#     - 결과에 한글이 표함된 경우 UTF-8로 디코팅 : *string*.**decode**('utf-8')

# %% [markdown]
# ## Naver 검색 API 동작 방식
#    - start부터 display 수만큼 검색 결과를 json으로 가져옴
#    - 검색 결과는 json의 'items'에 들어 있음
#    - 검색 결과 수는 'display'에 들어 있음

# %%
# 네이버 검색 API 예제 기반으로 네이버 검색 API 동작 방식 확인 (검색 결과 모두 받기)
# rescode가 200인 동안 start를 증가시켜서 계속 검색 (테스트를 위해 start는 25이하로 제한)

# %% [markdown]
# # 3. json : JSON 데이터 파싱,생성 (built-in)
# * import json
# * JSON 문자열을 파이썬 객체로 변환 : *pyObject* = **json.loads**(*jsonString*)
# * 파이썬 객체를 JSON 문자열로 변환 : *jsonString* = **json.dumps**(*pyObject*)
#    - ensure_ascii=True : 한글일때는 False로 변경하기
#    - indent=None : 가독성을 높이기 위해 숫자 지정하기
# * JSON 파일을 파이썬 객체로 로딩 : *pyObject* = **json.load**()
# * 파이썬 객체를 JSON 파일에 저장 : **json.dump**(*pyObject*, *fileObject*)
#
# https://docs.python.org/3/library/json.html

# %% [markdown]
# # [ 프로그램 Workflow ]
# 1. 네이버 뉴스 API로 Crawling : **searchNaverNews()** -> 파이썬 json 데이터
#    1. url 구성하기
#    1. url 접속과 검색 요청하기
#    1. url 요청결과를 응답 json으로 받기 (json.loads)
# 1. 응답데이터를 리스트에 저장 : **setNewSearchResult** -> List
# 1. 응답데이터가 없을 때까지 반복
#    1. 파이썬 예외처리 : try + except + else + finally
# 1. 리스트를 CSV 파일로 저장 : **saveSearchResult** (pd.to_csv)

# %%
# 검색 API 호출, 응답을 JSON 데이터로 return하는 함수 작성
# API 호출 결과에 문제가 있을 경우 exception으로 처리
# exception 발생 시 exception과 호출 url 확인
import urllib.request
import json

def searchNaverNews(keyword, start, display):

    client_id = "8os69VYnBk5H5QpLkte1"
    client_secret = "kPicTeAw_3"
    
    # 한글 검색어 안전하게 변환
    encText = urllib.parse.quote(keyword)
    
    # url + query 생성
    # url = "https://openapi.naver.com/v1/search/"검색필터 넣는 곳"?query=" + encText
    url = "https://openapi.naver.com/v1/search/news?query=" + encText # JSON 결과

    # request message 구성
    new_url = url + f"&start={start}&display={display}"
    request = urllib.request.Request(new_url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    
    resultJSON = None
    try :  
        # request -> response 받아오기
        response = urllib.request.urlopen(request)
            
        # 받아온 결과가 정상인지 확인
        rescode = response.getcode()
        if(rescode==200):
            # 정상이면 데이터 읽어오기
            response_body = response.read()
            #print(response_body.decode('utf-8')) # 한글이 있을 시 utf-8
            resultJSON = json.loads(response_body.decode('utf-8'))
        else:
            print("Error Code:" + rescode)
    except Exception as e :
        print(e)
        print(f"Error : {new_url}")
        
    return resultJSON

# %%
#응답데이터를 리스트에 저장 (검색 결과는 json의 'items'에 들어 있음)
def setNewsSearchResult(resultAll, resultJSON):
    for result in resultJSON['items'] :
        resultAll.append(result)

# %%
# JSON의 list를 dataframe으로 변환하여 csv 파일로 저장
def saveSearchResult_CSV(json_list, filename):
    import pandas as pd
    data_df = pd.DataFrame(json_list)
    data_df.to_csv(filename)
    print(f"{filename} SAVED")

# %%
# 검색어 입력
keyword = "비트코인"

# API 호출 결과 전송된 JSON이 없거나, 전송된 JSON에 검색 결과가 없을 때까지
# 검색 결과를 JSON의 list로 저장 후 검색 API 추가 호출


# 검색 결과를 저장할 list 초기화
resultAll = []

# 첫 검색 API 호출
start = 1
display = 10
resultJSON = searchNaverNews(keyword, start, display)
#print(resultJSON) #값이 잘 들어왔는지 확인할것, 제대로 안 받으면 None을 출력한다. 

while (resultJSON != None) and (resultJSON['display'] > 0 and start != 101) :
    # 응답데이터 정리하여 리스트 저장
    setNewsSearchResult(resultAll, resultJSON)
 
    # 다음 검색 API 호출을 위한 파라미터 조정
    start += display
    
    # API 호출
    resultJSON = searchNaverNews(keyword, start, display)

    # API 호출 성공 여부 출력
    if resultJSON != None :
        print(f"{keyword} [{start}] : Search Request Success")
    else :
        print(f"{keyword} [{start}] : error")

# 리스트를 csv 파일로 저장
filename = f"./{keyword}_naver_news.csv"
saveSearchResult_CSV(resultAll, filename)
# Out:
# 비트코인 [11] : Search Request Success
# 비트코인 [21] : Search Request Success
# 비트코인 [31] : Search Request Success
# 비트코인 [41] : Search Request Success
# 비트코인 [51] : Search Request Success
# 비트코인 [61] : Search Request Success
# 비트코인 [71] : Search Request Success
# 비트코인 [81] : Search Request Success
# 비트코인 [91] : Search Request Success
# 비트코인 [101] : Search Request Success
# ./비트코인_naver_news.csv SAVED

# %%
# 저장한 파일을 dataframe으로 loading 해보기
import pandas as pd
data_df = pd.read_csv(filename)
data_df.head()
# Out:
#    Unnamed: 0                                              title  \
# 0           0                 리플(엑스알피) 넥라인 저항선...시세 30달러 도달 전망은?
# 1           1              하이퍼리퀴드 고래 트레이더는 실제 사이버범죄자, 도난 자금으로 거래
# 2           2                     주광덕 남양주시장, '제52회 상공의 날' 기념식 참석
# 3           3  &quot;<b>비트코인</b> 2012년과 닮았다&quot;… 전문가의 강력한 X...
# 4           4   압수 중 사라진 <b>비트코인</b> 1476개 어디로... 영화같은 재판 광주서 시작
#
#                                         originallink  \
# 0  https://www.cbci.co.kr/news/articleView.html?i...
# 1            https://www.tokenpost.kr/article-229828
# 2  https://www.job-post.co.kr/news/articleView.ht...
# 3                      http://coinreaders.com/151290
# 4  https://www.ohmynews.com/NWS_Web/View/at_pg.as...
#
#                                                 link  \
# 0  https://www.cbci.co.kr/news/articleView.html?i...
# 1            https://www.tokenpost.kr/article-229828
# 2  https://www.job-post.co.kr/news/articleView.ht...
# 3                      http://coinreaders.com/151290
# 4  https://n.news.naver.com/mnews/article/047/000...
#
#                                          description  \
# 0  한편 18일 미국 <b>비트코인</b> 현물 ETF에서 2억826만 달러(약 3,0...
# 1  논란은 한 트레이더가 <b>비트코인</b>에 대한 대규모 숏포지션으로 900만 달러...
# 2  이날 조찬 강연포럼에서는 <b>비트코인</b>과 블록체인 분야의 선구자로 알려진 오...
# 3  그는 XRP의 현재 상황을 2012년의 <b>비트코인</b>과 비교하며, &quot...
# 4  ▲  <b>비트코인</b>. ⓒ pexels 2021년 경찰의 도박사이트 수익금 압...
#
#                            pubDate
# 0  Wed, 19 Mar 2025 18:00:00 +0900
# 1  Wed, 19 Mar 2025 17:58:00 +0900
# 2  Wed, 19 Mar 2025 17:58:00 +0900
# 3  Wed, 19 Mar 2025 17:56:00 +0900
# 4  Wed, 19 Mar 2025 17:54:00 +0900
